# %%
import pandas as pd

# %%
data=pd.read_csv("Employee_Performance.csv")

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
dept_rating=pd.crosstab(data['EmpDepartment'],data['PerformanceRating'])

# %%
dept_rating
# Out:
# PerformanceRating        2    3   4
# EmpDepartment
# Data Science             1   17   2
# Development             13  304  44
# Finance                 15   30   4
# Human Resources         10   38   6
# Research & Development  68  234  41
# Sales                   87  251  35

# %%
dept_rating.plot(kind='bar', stacked=True)

# %%
dept_rating['total']=dept_rating.sum(axis=1)

# %%
dept_rating=dept_rating.apply(lambda x: round(100*x/dept_rating['total']))

# %%
dept_rating.drop('total',axis=1,inplace=True)

# %%
dept_rating
# Out:
# PerformanceRating          2     3     4
# EmpDepartment
# Data Science             5.0  85.0  10.0
# Development              4.0  84.0  12.0
# Finance                 31.0  61.0   8.0
# Human Resources         19.0  70.0  11.0
# Research & Development  20.0  68.0  12.0
# Sales                   23.0  67.0   9.0

# %%
dept_rating.plot(kind='bar',stacked=True)

# %%
data.shape
# Out:
# (1200, 28)

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
training_data=data.copy()

# %%
training_data
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
output_data=data['Attrition']

# %%
training_data.drop('Attrition',axis=1,inplace=True)

# %%
training_data.copy()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
data['Gender'] = encoder.fit_transform(data['Gender'])

# %%
training_data.drop('EmpNumber', axis=1, inplace= True)

# %%
text_columns= training_data.select_dtypes('object')

# %%
for col_name in text_columns:
    encoder=LabelEncoder()
    training_data[col_name] = encoder.fit_transform(training_data[col_name])

# %%
training_data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpLastSalaryHikePercent  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X,x_test,Y,y_test = train_test_split(training_data,output_data,
                                    test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
predictions = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(predictions,y_test)
# Out:
# 0.8527777777777777

# %%
features =X.columns

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
import pydotplus
from sklearn import tree
dot_data= StringIO()
tree.export_graphviz(model,out_file=dot_data,
                   feature_names=features)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("Hiring.png")
Image(graph.create_png())

# %%
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
training_data.head()
# Out:
#    Age  Gender  EducationBackground  MaritalStatus  EmpDepartment  EmpJobRole  \
# 0   32       1                    2              2              5          13
# 1   47       1                    2              2              5          13
# 2   40       1                    1              1              5          13
# 3   41       1                    0              0              3           8
# 4   60       1                    2              2              5          13
#
#    BusinessTravelFrequency  DistanceFromHome  EmpEducationLevel  \
# 0                        2                10                  3
# 1                        2                14                  4
# 2                        1                 5                  4
# 3                        2                10                  4
# 4                        2                16                  4
#
#    EmpEnvironmentSatisfaction  ...  EmpLastSalaryHikePercent  \
# ...

# %%
training_data= data[['OverTime','EmpJobRole','Age',
                    'EmpEnvironmentSatisfaction']]

# %%
text_columns=training_data.select_dtypes('object')

# %%
for col_name in text_columns:
    encoder=LabelEncoder()
    training_data[col_name]=encoder.fit_transform(training_data[col_name])
# Out:
# C:\Users\Archana\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
output_data=data['Attrition']

# %%
X,x_test,Y,y_test=train_test_split(training_data,output_data,
                                  test_size=0.3,random_state=42)

# %%
model=DecisionTreeClassifier()

# %%
Y.head()
# Out:
# 522     No
# 213     No
# 120     No
# 917     No
# 1067    No
# Name: Attrition, dtype: object

# %%
Y.head()
# Out:
# 522     No
# 213     No
# 120     No
# 917     No
# 1067    No
# Name: Attrition, dtype: object

# %%
model.fit(X,Y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ###### RANDOM FOREST BAGGING

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model=RandomForestClassifier(n_estimators=25)

# %%
output_data
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 1195     No
# 1196     No
# 1197     No
# 1198     No
# 1199    Yes
# Name: Attrition, Length: 1200, dtype: object

# %%
training_data.head(2)
# Out:
#    OverTime  EmpJobRole  Age  EmpEnvironmentSatisfaction
# 0         0          13   32                           4
# 1         0          13   47                           4

# %%
columns=['OverTime','EmpJobRole']

# %%
for col in columns:
    encoder=LabelEncoder()
    training_data[col]=encoder.fit_transform(training_data[col])
# Out:
# C:\Users\Archana\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
training_data.head()
# Out:
#    OverTime  EmpJobRole  Age  EmpEnvironmentSatisfaction
# 0         0          13   32                           4
# 1         0          13   47                           4
# 2         1          13   40                           4
# 3         0           8   41                           2
# 4         0          13   60                           1

# %%
X,x_test,Y,y_test=train_test_split(training_data,output_data,
                                  test_size=0.3,random_state=42)

# %%
rf_model.fit(X,Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=25,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rf_predictions= rf_model.predict(x_test)

# %%
accuracy_score(rf_predictions,y_test)
# Out:
# 0.8222222222222222

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting=VotingClassifier(estimators=[('lr',LogisticRegression()),
                                    ('knn',KNeighborsClassifier()),
                                   ('dt',DecisionTreeClassifier())])

# %%
voting.fit(X,Y)
# Out:
# C:\Users\Archana\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='warn',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=None,
#                                                  solver='warn', tol=0.0001,
#                                                  verbose=0, warm_start=False)),
#                              ('knn',
# ...

# %%
voting_predictions= voting.predict(x_test)

# %%
accuracy_score(voting_predictions,y_test)
# Out:
# 0.8444444444444444
